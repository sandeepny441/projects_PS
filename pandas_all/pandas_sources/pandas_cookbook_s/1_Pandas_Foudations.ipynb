# %% [raw]
# 1. # Dissecting the anatomy of a DataFrame
#
# 2. Accessing the main DataFrame components
#
# 3. Understanding data types
#
# 4. Selecting a single column of data as a Series
#
# 5. Calling Series methods
#
# 6. Working with operators on a Series
#
# 7. Chaining Series methods together
#
# 8. Making the index meaningful
#
# 9. Renaming row and column names
#
# 10. Creating and deleting columns

# %%
import pandas as pd
import numpy as np 
pd.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ## 1.  Dissecting the anatomy of a DataFrame

# %%
df_movies = pd.read_csv("movie.csv")
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# ### 2. Accessing the main DataFrame components

# %%
index = df_movies.index
columns = df_movies.columns
data = df_movies.values

# %%
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
data[:1]
# Out:
# array([['Color', 'James Cameron', 723.0, 178.0, 0.0, 855.0,
#         'Joel David Moore', 1000.0, 760505847.0,
#         'Action|Adventure|Fantasy|Sci-Fi', 'CCH Pounder', 'Avatar',
#         886204, 4834, 'Wes Studi', 0.0,
#         'avatar|future|marine|native|paraplegic',
#         'http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1', 3054.0,
#         'English', 'USA', 'PG-13', 237000000.0, 2009.0, 936.0, 7.9, 1.78,
#         33000]], dtype=object)

# %%
type(index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(data)
# Out:
# numpy.ndarray

# %%
issubclass(pd.RangeIndex, pd.Index) # RangeIndex is a subclass of Index
# Out:
# True

# %%
index.values
# Out:
# array([   0,    1,    2, ..., 4913, 4914, 4915], dtype=int64)

# %%
columns.values
# Out:
# array(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'], dtype=object)

# %%
data
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %% [markdown]
# ### 3. Understanding data types

# %%
df_movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
df_movies.dtypes.value_counts() #get_dtype_value_counts() is replaced fffffrom 0.25.0
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %% [markdown]
# ### 4. Selecting a single column of data as a Series

# %%
directors = df_movies.director_name

# %%
directors.to_frame()
# Out:
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 4911        Scott Smith
# 4912                NaN
# 4913   Benjamin Roberds
# 4914        Daniel Hsia
# 4915           Jon Gunn
#
# [4916 rows x 1 columns]

# %% [markdown]
# ### 5. Calling Series methods

# %%
series_methods = set(dir(pd.Series))
len(series_methods)
# Out:
# 433

# %%
dataframe_methods = set(dir(pd.DataFrame))
len(dataframe_methods)
# Out:
# 430

# %%
len(series_methods & dataframe_methods)
# Out:
# 377

# %%
df_movies.director_name.head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
df_movies.director_name.value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Spike Lee           16
#                     ..
# James Bridges        1
# Deb Hagan            1
# Marcus Nispel        1
# Charlie Kaufman      1
# Hank Braxtan         1
# Name: director_name, Length: 2397, dtype: int64

# %%
directors = df_movies.director_name

# %%
directors.size
# Out:
# 4916

# %%
directors.shape
# Out:
# (4916,)

# %%
len(directors)
# Out:
# 4916

# %%
directors.count()
# Out:
# 4814

# %%
actor_1_fb_likes = df_movies['actor_1_facebook_likes']

# %%
actor_1_fb_likes.count()
# Out:
# 4909

# %%
actor_1_fb_likes.value_counts()
# Out:
# 1000.0     436
# 11000.0    206
# 2000.0     189
# 3000.0     150
# 12000.0    131
#           ...
# 362.0        1
# 216.0        1
# 859.0        1
# 225.0        1
# 334.0        1
# Name: actor_1_facebook_likes, Length: 877, dtype: int64

# %%
actor_1_fb_likes.min(), actor_1_fb_likes.max(), actor_1_fb_likes.std()
# Out:
# (0.0, 640000.0, 15106.986883848309)

# %%
actor_1_fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
actor_1_fb_likes.quantile(.2)
# Out:
# 510.0

# %%
actor_1_fb_likes.quantile([.1, .2, .3, .4, .5,.6, .7, .8, .9])
# Out:
# 0.1      240.0
# 0.2      510.0
# 0.3      694.0
# 0.4      854.0
# 0.5      982.0
# 0.6     1000.0
# 0.7     8000.0
# 0.8    13000.0
# 0.9    18000.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
directors.isnull().sum()
# Out:
# 102

# %%
actor_1_fb_likes.isnull().sum()
# Out:
# 7

# %%
actor_1_fb_likes_filled = actor_1_fb_likes.fillna(0)

# %%
actor_1_fb_likes_filled.isnull().sum()
# Out:
# 0

# %%
actor_1_fb_likes_dropped = actor_1_fb_likes.dropna()

# %%
actor_1_fb_likes_dropped.size
# Out:
# 4909

# %%
directors.value_counts(normalize=True)
# Out:
# Steven Spielberg    0.005401
# Woody Allen         0.004570
# Clint Eastwood      0.004155
# Martin Scorsese     0.004155
# Spike Lee           0.003324
#                       ...
# James Bridges       0.000208
# Deb Hagan           0.000208
# Marcus Nispel       0.000208
# Charlie Kaufman     0.000208
# Hank Braxtan        0.000208
# Name: director_name, Length: 2397, dtype: float64

# %%
directors.hasnans
# Out:
# True

# %%
directors.notnull().sum(), directors.isnull().sum()
# Out:
# (4814, 102)

# %%
directors.notnull().sum() + directors.isnull().sum() == len(directors)
# Out:
# True

# %% [markdown]
# ### 6. Working with operators on a Series

# %%
imdb_score =df_movies['imdb_score']

# %%
imdb_score
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 4911    7.7
# 4912    7.5
# 4913    6.3
# 4914    6.3
# 4915    6.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score + 1
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
#        ...
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score * 2
# Out:
# 0       15.8
# 1       14.2
# 2       13.6
# 3       17.0
# 4       14.2
#         ...
# 4911    15.4
# 4912    15.0
# 4913    12.6
# 4914    12.6
# 4915    13.2
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score // 7
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 4911    1.0
# 4912    1.0
# 4913    0.0
# 4914    0.0
# 4915    0.0
# Name: imdb_score, Length: 4916, dtype: float64

# %%
 imdb_score > 7
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 4911     True
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: imdb_score, Length: 4916, dtype: bool

# %%
directors = df_movies['director_name']

# %%
 directors == 'James Cameron'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %% [raw]
# # In Python if you want to compare a value to a list of values, we need to use a FOR loop
# # In Pandas, we take adv. of Numpy's VECTORIZED Operations

# %%
results = [imdb_score.add(100), imdb_score.mul(2) ,imdb_score.floordiv(3) ,imdb_score.gt(10)]

# %%
for result in results:
    print(result)
    print("------------------")
# Out:
# 0       107.9
# 1       107.1
# 2       106.8
# 3       108.5
# 4       107.1
#         ...
# 4911    107.7
# 4912    107.5
# 4913    106.3
# 4914    106.3
# 4915    106.6
# Name: imdb_score, Length: 4916, dtype: float64
# ------------------
# 0       15.8
# 1       14.2
# 2       13.6
# 3       17.0
# 4       14.2
#         ...
# 4911    15.4
# 4912    15.0
# 4913    12.6
# 4914    12.6
# 4915    13.2
# Name: imdb_score, Length: 4916, dtype: float64
# ------------------
# 0       2.0
# 1       2.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 4911    2.0
# 4912    2.0
# 4913    2.0
# 4914    2.0
# 4915    2.0
# Name: imdb_score, Length: 4916, dtype: float64
# ------------------
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# Name: imdb_score, Length: 4916, dtype: bool
# ------------------

# %% [markdown]
# ### 7. Chaining Series methods together - METHOD CHAINING

# %%
directors.value_counts().head(3)
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Name: director_name, dtype: int64

# %%
actor_1_fb_likes.isnull().sum()
# Out:
# 7

# %%
actor_1_fb_likes.fillna(0).astype(int)
# Out:
# 0        1000
# 1       40000
# 2       11000
# 3       27000
# 4         131
#         ...
# 4911      637
# 4912      841
# 4913        0
# 4914      946
# 4915       86
# Name: actor_1_facebook_likes, Length: 4916, dtype: int32

# %%
actor_1_fb_likes.isnull().mean()
# Out:
# 0.0014239218877135883

# %%
(actor_1_fb_likes.fillna(0)
.astype(int)
.head())
#use paranthesis if you want to write code in multiple lines
# Out:
# 0     1000
# 1    40000
# 2    11000
# 3    27000
# 4      131
# Name: actor_1_facebook_likes, dtype: int32

# %% [raw]
# 1. Debugging will be an iseue with Method Caining
# 2. The intermediate results are not available in to track the error

# %% [markdown]
# ### 8. Making the index meaningful

# %%
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df_movies.set_index('movie_title')
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
df_movies = pd.read_csv('movie.csv', index_col='director_name')
df_movies.head()
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Doug Walker          NaN                     NaN       NaN
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
# Doug Walker                          131.0                     NaN
#
#                        actor_2_name  actor_1_facebook_likes        gross  \
# director_name
# James Cameron      Joel David Moore                  1000.0  760505847.0
# ...

# %%
 df_movies = pd.read_csv('movie.csv', index_col='movie_title')

# %%
df_movies.head(2)
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# Avatar                                                     855.0
# Pirates of the Caribbean: At World's End                  1000.0
#
#                                               actor_2_name  \
# movie_title
# ...

# %%
# set_index and read_csv wi drop the actual index by default, we can keep the index by 
# keeping the drop = False flag

# %%
df_movies.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
df_movies.reset_index()
# Out:
#                                      movie_title  color      director_name  \
# 0                                         Avatar  Color      James Cameron
# 1       Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# 2                                        Spectre  Color         Sam Mendes
# 3                          The Dark Knight Rises  Color  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                          ...    ...                ...
# 4911                     Signed Sealed Delivered  Color        Scott Smith
# 4912                               The Following  Color                NaN
# 4913                        A Plague So Pleasant  Color   Benjamin Roberds
# 4914                            Shanghai Calling  Color        Daniel Hsia
# 4915                           My Date with Drew  Color           Jon Gunn
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# ...

# %% [markdown]
# ### 9. Renaming row and column names

# %%
 df_movies= pd.read_csv('movie.csv', index_col='movie_title')

# %%
idx_rename = {'Avatar':'Ratava', 'Spectre': 'Ertceps'}
col_rename = {'director_name':'Director Name', 'num_critic_for_reviews': 'Critical Reviews'}

# %%
movie_renamed = df_movies.rename(index=idx_rename, columns=col_rename)

# %%
movie_renamed.head()
# Out:
#                                             color      Director Name  \
# movie_title
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# movie_title
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# ...

# %%
index = df_movies.index
columns = df_movies.columns

# %%
index_list = index.tolist()
columns_list = columns.tolist()

# %%
index_list[0] = 'Ratava'
index_list[2] = 'Ertceps'
index_list[3] = 'Three'
columns_list[1] = 'Director Name'
columns_list[2] = 'Critical Reviews'

# %%
df_movies.index = index_list
df_movies.columns = columns_list

# %%
df_movies.head()
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# Three                                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# Three                                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %% [markdown]
# ### 10. Creating and deleting columns

# %%
df_movies['has_seen'] = 0

# %%
df_movies.columns
# Out:
# Index(['color', 'Director Name', 'Critical Reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes', 'has_seen'],
#       dtype='object')

# %%
df_movies['actor_director_facebook_likes'] = (df_movies['actor_1_facebook_likes'] +\
                                             df_movies['actor_2_facebook_likes'] +\
                                             df_movies['actor_3_facebook_likes'] +\
                                             df_movies['director_facebook_likes'])

# %%
df_movies
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# Three                                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             Critical Reviews  duration  \
# ...

# %%
df_movies['actor_director_facebook_likes'].isnull().sum()
# Out:
# 122

# %%
len(df_movies)
# Out:
# 4916

# %%
df_movies['actor_director_facebook_likes'].isnull().sum()
# Out:
# 122

# %%
df_movies['all_null'] = ''

# %%
df_movies['all_null'].sum()

# If all the valus are nulls, then the result also will be null
# if atleast one of the values is not null, the result will be equal to sum of 
# not nulls as nulls are considered to be ZERO in this case
# Out:
# ''

# %%
df_movies['is_cast_likes_more'] = (df_movies['cast_total_facebook_likes'] >= df_movies['actor_director_facebook_likes'])

# %%
df_movies['is_cast_likes_more'].sum()
# Out:
# 3851

# %%
df_movies['is_cast_likes_more'].all()
# Out:
# False

# %%
df_movies.head()
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# Three                                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# Three                                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %%
df_movies.columns.tolist()
# Out:
# ['color',
#  'Director Name',
#  'Critical Reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes',
#  'has_seen',
#  'actor_director_facebook_likes',
#  'all_null',
#  'is_cast_likes_more']

# %%
df_movies['actor_total_facebook_likes'] = (df_movies['actor_1_facebook_likes'] +
 df_movies['actor_2_facebook_likes'] +
 df_movies['actor_3_facebook_likes'])

# %%
df_movies['actor_total_facebook_likes'] =  df_movies['actor_total_facebook_likes'].fillna(0)

# %%
df_movies['is_cast_likes_more'] = (df_movies['cast_total_facebook_likes'] >=
 df_movies['actor_total_facebook_likes'])

# %%
df_movies['is_cast_likes_more'].all()
# Out:
# True

# %%
df_movies['pct_actor_cast_like'] = (df_movies['actor_total_facebook_likes'] 
 / df_movies['cast_total_facebook_likes'])

# %%
(df_movies['pct_actor_cast_like'].min(),
 df_movies['pct_actor_cast_like'].max())
# Out:
# (0.0, 1.0)

# %%
df_movies.head()
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# Three                                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# Three                                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %%
df_movies['actor_total_facebook_likes'].head()
# Out:
# Ratava                                         2791.0
# Pirates of the Caribbean: At World's End      46000.0
# Ertceps                                       11554.0
# Three                                         73000.0
# Star Wars: Episode VII - The Force Awakens        0.0
# Name: actor_total_facebook_likes, dtype: float64

# %%
df_movies.drop(['duration'], axis = 'columns')
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# Three                                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             Critical Reviews  \
# Ratava                                                 723.0
# ...

# %%
df_movies.drop(['Ratava'], axis = 'rows')
# Out:
#                                             color      Director Name  \
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# Three                                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# John Carter                                 Color     Andrew Stanton
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             Critical Reviews  duration  \
# ...

# %%
df_movies.drop(['Three'])
# Out:
#                                             color     Director Name  \
# Ratava                                      Color     James Cameron
# Pirates of the Caribbean: At World's End    Color    Gore Verbinski
# Ertceps                                     Color        Sam Mendes
# Star Wars: Episode VII - The Force Awakens    NaN       Doug Walker
# John Carter                                 Color    Andrew Stanton
# ...                                           ...               ...
# Signed Sealed Delivered                     Color       Scott Smith
# The Following                               Color               NaN
# A Plague So Pleasant                        Color  Benjamin Roberds
# Shanghai Calling                            Color       Daniel Hsia
# My Date with Drew                           Color          Jon Gunn
#
#                                             Critical Reviews  duration  \
# Ratava                                                 723.0     178.0
# ...

# %%
df_movies.columns.tolist()
# Out:
# ['color',
#  'Director Name',
#  'Critical Reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes',
#  'has_seen',
#  'actor_director_facebook_likes',
#  'all_null',
#  'is_cast_likes_more',
#  'actor_total_facebook_likes',
#  'pct_actor_cast_like']

# %%
len(df_movies.columns)
# Out:
# 33

# %%
 profit_index = df_movies.columns.get_loc('gross') + 1

# %%
profit_index
# Out:
# 9

# %%
df_movies.insert(loc=profit_index,column='profit',value=df_movies['gross'] - df_movies['budget'])

# %%
df_movies.columns.tolist()
# Out:
# ['color',
#  'Director Name',
#  'Critical Reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'profit',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes',
#  'has_seen',
#  'actor_director_facebook_likes',
#  'all_null',
#  'is_cast_likes_more',
#  'actor_total_facebook_likes',
#  'pct_actor_cast_like']

# %%
len(df_movies.columns)
# Out:
# 34

# %%
del df_movies['actor_director_facebook_likes']

# %%
df_movies.columns.tolist()
# Out:
# ['color',
#  'Director Name',
#  'Critical Reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'profit',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes',
#  'has_seen',
#  'all_null',
#  'is_cast_likes_more',
#  'actor_total_facebook_likes',
#  'pct_actor_cast_like']

# %%
len(df_movies.columns)
# Out:
# 33

# %%
print('end')
# Out:
# end
