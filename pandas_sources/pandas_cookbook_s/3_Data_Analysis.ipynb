# %% [markdown]
# # Topics
#     1. Developing a data analysis routine
#     2. Reducing memory by changing data types
#     3. Selecting the smallest of the largest
#     4. Selecting the largest of each group by sorting
#     5. Replicating nlargest with sort_values
#     6. Calculating a trailing stop order price

# %% [markdown]
# ### 1. Developing a data analysis routine

# %%
import pandas as pd 
import numpy as np

# %%
df_college = pd.read_csv('data/college.csv')

# %%
df_college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
# 4    0.0243     0.0137    0.0892         1   0.7347    0.7554   0.1270
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
# 2            40100               23370
# 3            45500               24097
# 4            26600             33118.5
#
# [5 rows x 27 columns]

# %%
df_college.shape
# Out:
# (7535, 27)

# %%
df_college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   INSTNM              7535 non-null   object
#  1   CITY                7535 non-null   object
#  2   STABBR              7535 non-null   object
#  3   HBCU                7164 non-null   float64
#  4   MENONLY             7164 non-null   float64
#  5   WOMENONLY           7164 non-null   float64
#  6   RELAFFIL            7535 non-null   int64
#  7   SATVRMID            1185 non-null   float64
#  8   SATMTMID            1196 non-null   float64
#  9   DISTANCEONLY        7164 non-null   float64
#  10  UGDS                6874 non-null   float64
#  11  UGDS_WHITE          6874 non-null   float64
#  12  UGDS_BLACK          6874 non-null   float64
#  13  UGDS_HISP           6874 non-null   float64
#  14  UGDS_ASIAN          6874 non-null   float64
#  15  UGDS_AIAN           6874 non-null   float64
#  16  UGDS_NHPI           6874 non-null   float64
#  17  UGDS_2MOR           6874 non-null   float64
#  18  UGDS_NRA            6874 non-null   float64
#  19  UGDS_UNKN           6874 non-null   float64
#  20  PPTUG_EF            6853 non-null   float64
#  21  CURROPER            7535 non-null   int64
#  22  PCTPELL             6849 non-null   float64
#  23  PCTFLOAN            6849 non-null   float64
#  24  UG25ABV             6718 non-null   float64
#  25  MD_EARN_WNE_P10     6413 non-null   object
#  26  GRAD_DEBT_MDN_SUPP  7503 non-null   object
# dtypes: float64(20), int64(2), object(5)
# memory usage: 1.6+ MB

# %%
df_college.size
# Out:
# 203445

# %%
df_college.describe(include = 'object').T
# Out:
#                    count unique                         top  freq
# INSTNM              7535   7535  Everest Institute-Bensalem     1
# CITY                7535   2514                    New York    87
# STABBR              7535     59                          CA   773
# MD_EARN_WNE_P10     6413    598           PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038           PrivacySuppressed  1510

# %%
df_college.describe(include = [np.number]).T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# UGDS_ASIAN    6874.0     0.033544     0.073777    0.0    0.002500    0.01290
# UGDS_AIAN     6874.0     0.013813     0.070196    0.0    0.000000    0.00260
# UGDS_NHPI     6874.0     0.004569     0.033125    0.0    0.000000    0.00000
# UGDS_2MOR     6874.0     0.023950     0.031288    0.0    0.000000    0.01750
# UGDS_NRA      6874.0     0.016086     0.050172    0.0    0.000000    0.00000
# UGDS_UNKN     6874.0     0.045181     0.093440    0.0    0.000000    0.01430
# PPTUG_EF      6853.0     0.226639     0.246470    0.0    0.000000    0.15040
# CURROPER      7535.0     0.923291     0.266146    0.0    1.000000    1.00000
# PCTPELL       6849.0     0.530643     0.225544    0.0    0.357800    0.52150
# PCTFLOAN      6849.0     0.522211     0.283616    0.0    0.332900    0.58330
# UG25ABV       6718.0     0.410021     0.228939    0.0    0.241500    0.40075
#
#                       75%          max
# HBCU             0.000000       1.0000
# MENONLY          0.000000       1.0000
# WOMENONLY        0.000000       1.0000
# RELAFFIL         0.000000       1.0000
# SATVRMID       555.000000     765.0000
# SATMTMID       565.000000     785.0000
# DISTANCEONLY     0.000000       1.0000
# UGDS          1929.500000  151558.0000
# UGDS_WHITE       0.747875       1.0000
# UGDS_BLACK       0.257700       1.0000
# UGDS_HISP        0.198875       1.0000
# UGDS_ASIAN       0.032700       0.9727
# UGDS_AIAN        0.007300       1.0000
# UGDS_NHPI        0.002500       0.9983
# UGDS_2MOR        0.033900       0.5333
# UGDS_NRA         0.011700       0.9286
# UGDS_UNKN        0.045400       0.9027
# PPTUG_EF         0.376900       1.0000
# CURROPER         1.000000       1.0000
# PCTPELL          0.712900       1.0000
# PCTFLOAN         0.745000       1.0000
# UG25ABV          0.572275       1.0000

# %%
df_college.describe(include = np.number).T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# UGDS_ASIAN    6874.0     0.033544     0.073777    0.0    0.002500    0.01290
# UGDS_AIAN     6874.0     0.013813     0.070196    0.0    0.000000    0.00260
# UGDS_NHPI     6874.0     0.004569     0.033125    0.0    0.000000    0.00000
# UGDS_2MOR     6874.0     0.023950     0.031288    0.0    0.000000    0.01750
# UGDS_NRA      6874.0     0.016086     0.050172    0.0    0.000000    0.00000
# UGDS_UNKN     6874.0     0.045181     0.093440    0.0    0.000000    0.01430
# PPTUG_EF      6853.0     0.226639     0.246470    0.0    0.000000    0.15040
# CURROPER      7535.0     0.923291     0.266146    0.0    1.000000    1.00000
# PCTPELL       6849.0     0.530643     0.225544    0.0    0.357800    0.52150
# PCTFLOAN      6849.0     0.522211     0.283616    0.0    0.332900    0.58330
# UG25ABV       6718.0     0.410021     0.228939    0.0    0.241500    0.40075
#
#                       75%          max
# HBCU             0.000000       1.0000
# MENONLY          0.000000       1.0000
# WOMENONLY        0.000000       1.0000
# RELAFFIL         0.000000       1.0000
# SATVRMID       555.000000     765.0000
# SATMTMID       565.000000     785.0000
# DISTANCEONLY     0.000000       1.0000
# UGDS          1929.500000  151558.0000
# UGDS_WHITE       0.747875       1.0000
# UGDS_BLACK       0.257700       1.0000
# UGDS_HISP        0.198875       1.0000
# UGDS_ASIAN       0.032700       0.9727
# UGDS_AIAN        0.007300       1.0000
# UGDS_NHPI        0.002500       0.9983
# UGDS_2MOR        0.033900       0.5333
# UGDS_NRA         0.011700       0.9286
# UGDS_UNKN        0.045400       0.9027
# PPTUG_EF         0.376900       1.0000
# CURROPER         1.000000       1.0000
# PCTPELL          0.712900       1.0000
# PCTFLOAN         0.745000       1.0000
# UG25ABV          0.572275       1.0000

# %%
df_college.describe(include = np.object).T
# Out:
#                    count unique                         top  freq
# INSTNM              7535   7535  Everest Institute-Bensalem     1
# CITY                7535   2514                    New York    87
# STABBR              7535     59                          CA   773
# MD_EARN_WNE_P10     6413    598           PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038           PrivacySuppressed  1510

# %%
df_college.describe(include = [np.object, np.number, pd.Categorical]).T
# Out:
#                    count unique                         top  freq        mean  \
# INSTNM              7535   7535  Everest Institute-Bensalem     1         NaN
# CITY                7535   2514                    New York    87         NaN
# STABBR              7535     59                          CA   773         NaN
# HBCU                7164    NaN                         NaN   NaN   0.0142379
# MENONLY             7164    NaN                         NaN   NaN  0.00921273
# WOMENONLY           7164    NaN                         NaN   NaN   0.0053043
# RELAFFIL            7535    NaN                         NaN   NaN    0.190975
# SATVRMID            1185    NaN                         NaN   NaN     522.819
# SATMTMID            1196    NaN                         NaN   NaN     530.765
# DISTANCEONLY        7164    NaN                         NaN   NaN  0.00558347
# UGDS                6874    NaN                         NaN   NaN     2356.84
# UGDS_WHITE          6874    NaN                         NaN   NaN    0.510207
# UGDS_BLACK          6874    NaN                         NaN   NaN    0.189997
# UGDS_HISP           6874    NaN                         NaN   NaN    0.161635
# UGDS_ASIAN          6874    NaN                         NaN   NaN   0.0335442
# UGDS_AIAN           6874    NaN                         NaN   NaN   0.0138126
# UGDS_NHPI           6874    NaN                         NaN   NaN   0.0045689
# UGDS_2MOR           6874    NaN                         NaN   NaN   0.0239503
# UGDS_NRA            6874    NaN                         NaN   NaN   0.0160858
# UGDS_UNKN           6874    NaN                         NaN   NaN   0.0451814
# PPTUG_EF            6853    NaN                         NaN   NaN    0.226639
# CURROPER            7535    NaN                         NaN   NaN    0.923291
# PCTPELL             6849    NaN                         NaN   NaN    0.530643
# PCTFLOAN            6849    NaN                         NaN   NaN    0.522211
# UG25ABV             6718    NaN                         NaN   NaN    0.410021
# MD_EARN_WNE_P10     6413    598           PrivacySuppressed   822         NaN
# GRAD_DEBT_MDN_SUPP  7503   2038           PrivacySuppressed  1510         NaN
#
#                           std  min       25%      50%       75%     max
# INSTNM                    NaN  NaN       NaN      NaN       NaN     NaN
# CITY                      NaN  NaN       NaN      NaN       NaN     NaN
# STABBR                    NaN  NaN       NaN      NaN       NaN     NaN
# HBCU                 0.118478    0         0        0         0       1
# MENONLY             0.0955465    0         0        0         0       1
# WOMENONLY           0.0726423    0         0        0         0       1
# RELAFFIL             0.393096    0         0        0         0       1
# SATVRMID              68.5789  290       475      510       555     765
# SATMTMID              73.4698  310       482      520       565     785
# DISTANCEONLY        0.0745189    0         0        0         0       1
# UGDS                  5474.28    0       117    412.5    1929.5  151558
# UGDS_WHITE           0.286958    0    0.2675   0.5557  0.747875       1
# UGDS_BLACK           0.224587    0  0.036125  0.10005    0.2577       1
# UGDS_HISP            0.221854    0    0.0276   0.0714  0.198875       1
# UGDS_ASIAN          0.0737772    0    0.0025   0.0129    0.0327  0.9727
# UGDS_AIAN           0.0701957    0         0   0.0026    0.0073       1
# UGDS_NHPI           0.0331251    0         0        0    0.0025  0.9983
# UGDS_2MOR            0.031288    0         0   0.0175    0.0339  0.5333
# UGDS_NRA            0.0501719    0         0        0    0.0117  0.9286
# UGDS_UNKN           0.0934404    0         0   0.0143    0.0454  0.9027
# PPTUG_EF              0.24647    0         0   0.1504    0.3769       1
# CURROPER             0.266146    0         1        1         1       1
# PCTPELL              0.225544    0    0.3578   0.5215    0.7129       1
# PCTFLOAN             0.283616    0    0.3329   0.5833     0.745       1
# UG25ABV              0.228939    0    0.2415  0.40075  0.572275       1
# MD_EARN_WNE_P10           NaN  NaN       NaN      NaN       NaN     NaN
# GRAD_DEBT_MDN_SUPP        NaN  NaN       NaN      NaN       NaN     NaN

# %%
#Generaly the describe ethod drops the categorical values. It only renders the continous values

# %%
df_college.describe().T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# UGDS_ASIAN    6874.0     0.033544     0.073777    0.0    0.002500    0.01290
# UGDS_AIAN     6874.0     0.013813     0.070196    0.0    0.000000    0.00260
# UGDS_NHPI     6874.0     0.004569     0.033125    0.0    0.000000    0.00000
# UGDS_2MOR     6874.0     0.023950     0.031288    0.0    0.000000    0.01750
# UGDS_NRA      6874.0     0.016086     0.050172    0.0    0.000000    0.00000
# UGDS_UNKN     6874.0     0.045181     0.093440    0.0    0.000000    0.01430
# PPTUG_EF      6853.0     0.226639     0.246470    0.0    0.000000    0.15040
# CURROPER      7535.0     0.923291     0.266146    0.0    1.000000    1.00000
# PCTPELL       6849.0     0.530643     0.225544    0.0    0.357800    0.52150
# PCTFLOAN      6849.0     0.522211     0.283616    0.0    0.332900    0.58330
# UG25ABV       6718.0     0.410021     0.228939    0.0    0.241500    0.40075
#
#                       75%          max
# HBCU             0.000000       1.0000
# MENONLY          0.000000       1.0000
# WOMENONLY        0.000000       1.0000
# RELAFFIL         0.000000       1.0000
# SATVRMID       555.000000     765.0000
# SATMTMID       565.000000     785.0000
# DISTANCEONLY     0.000000       1.0000
# UGDS          1929.500000  151558.0000
# UGDS_WHITE       0.747875       1.0000
# UGDS_BLACK       0.257700       1.0000
# UGDS_HISP        0.198875       1.0000
# UGDS_ASIAN       0.032700       0.9727
# UGDS_AIAN        0.007300       1.0000
# UGDS_NHPI        0.002500       0.9983
# UGDS_2MOR        0.033900       0.5333
# UGDS_NRA         0.011700       0.9286
# UGDS_UNKN        0.045400       0.9027
# PPTUG_EF         0.376900       1.0000
# CURROPER         1.000000       1.0000
# PCTPELL          0.712900       1.0000
# PCTFLOAN         0.745000       1.0000
# UG25ABV          0.572275       1.0000

# %%
df_college.describe(include = np.number).T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# UGDS_ASIAN    6874.0     0.033544     0.073777    0.0    0.002500    0.01290
# UGDS_AIAN     6874.0     0.013813     0.070196    0.0    0.000000    0.00260
# UGDS_NHPI     6874.0     0.004569     0.033125    0.0    0.000000    0.00000
# UGDS_2MOR     6874.0     0.023950     0.031288    0.0    0.000000    0.01750
# UGDS_NRA      6874.0     0.016086     0.050172    0.0    0.000000    0.00000
# UGDS_UNKN     6874.0     0.045181     0.093440    0.0    0.000000    0.01430
# PPTUG_EF      6853.0     0.226639     0.246470    0.0    0.000000    0.15040
# CURROPER      7535.0     0.923291     0.266146    0.0    1.000000    1.00000
# PCTPELL       6849.0     0.530643     0.225544    0.0    0.357800    0.52150
# PCTFLOAN      6849.0     0.522211     0.283616    0.0    0.332900    0.58330
# UG25ABV       6718.0     0.410021     0.228939    0.0    0.241500    0.40075
#
#                       75%          max
# HBCU             0.000000       1.0000
# MENONLY          0.000000       1.0000
# WOMENONLY        0.000000       1.0000
# RELAFFIL         0.000000       1.0000
# SATVRMID       555.000000     765.0000
# SATMTMID       565.000000     785.0000
# DISTANCEONLY     0.000000       1.0000
# UGDS          1929.500000  151558.0000
# UGDS_WHITE       0.747875       1.0000
# UGDS_BLACK       0.257700       1.0000
# UGDS_HISP        0.198875       1.0000
# UGDS_ASIAN       0.032700       0.9727
# UGDS_AIAN        0.007300       1.0000
# UGDS_NHPI        0.002500       0.9983
# UGDS_2MOR        0.033900       0.5333
# UGDS_NRA         0.011700       0.9286
# UGDS_UNKN        0.045400       0.9027
# PPTUG_EF         0.376900       1.0000
# CURROPER         1.000000       1.0000
# PCTPELL          0.712900       1.0000
# PCTFLOAN         0.745000       1.0000
# UG25ABV          0.572275       1.0000

# %%
len(df_college.describe(include = np.number).T)
# Out:
# 22

# %%
len(df_college.describe().T)
# Out:
# 22

# %%
len(df_college.describe(include = 'number').T)
# Out:
# 22

# %%
df_college.describe(include = 'number').T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# UGDS_ASIAN    6874.0     0.033544     0.073777    0.0    0.002500    0.01290
# UGDS_AIAN     6874.0     0.013813     0.070196    0.0    0.000000    0.00260
# UGDS_NHPI     6874.0     0.004569     0.033125    0.0    0.000000    0.00000
# UGDS_2MOR     6874.0     0.023950     0.031288    0.0    0.000000    0.01750
# UGDS_NRA      6874.0     0.016086     0.050172    0.0    0.000000    0.00000
# UGDS_UNKN     6874.0     0.045181     0.093440    0.0    0.000000    0.01430
# PPTUG_EF      6853.0     0.226639     0.246470    0.0    0.000000    0.15040
# CURROPER      7535.0     0.923291     0.266146    0.0    1.000000    1.00000
# PCTPELL       6849.0     0.530643     0.225544    0.0    0.357800    0.52150
# PCTFLOAN      6849.0     0.522211     0.283616    0.0    0.332900    0.58330
# UG25ABV       6718.0     0.410021     0.228939    0.0    0.241500    0.40075
#
#                       75%          max
# HBCU             0.000000       1.0000
# MENONLY          0.000000       1.0000
# WOMENONLY        0.000000       1.0000
# RELAFFIL         0.000000       1.0000
# SATVRMID       555.000000     765.0000
# SATMTMID       565.000000     785.0000
# DISTANCEONLY     0.000000       1.0000
# UGDS          1929.500000  151558.0000
# UGDS_WHITE       0.747875       1.0000
# UGDS_BLACK       0.257700       1.0000
# UGDS_HISP        0.198875       1.0000
# UGDS_ASIAN       0.032700       0.9727
# UGDS_AIAN        0.007300       1.0000
# UGDS_NHPI        0.002500       0.9983
# UGDS_2MOR        0.033900       0.5333
# UGDS_NRA         0.011700       0.9286
# UGDS_UNKN        0.045400       0.9027
# PPTUG_EF         0.376900       1.0000
# CURROPER         1.000000       1.0000
# PCTPELL          0.712900       1.0000
# PCTFLOAN         0.745000       1.0000
# UG25ABV          0.572275       1.0000

# %%
df_college.describe(include = [np.object, pd.Categorical]).T
# Out:
#                    count unique                         top  freq
# INSTNM              7535   7535  Everest Institute-Bensalem     1
# CITY                7535   2514                    New York    87
# STABBR              7535     59                          CA   773
# MD_EARN_WNE_P10     6413    598           PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038           PrivacySuppressed  1510

# %%
len(df_college.describe(include = [np.object, pd.Categorical]).T)
# Out:
# 5

# %%
len(df_college.describe(include = ['number', np.object, pd.Categorical]).T)
# Out:
# 27

# %%
#Schema of a DataFrame

# %% [markdown]
# ### 2. Reducing memory by changing data types

# %%
# The MEMORY usage is in BTYTES and not in bits

# %%
different_cols = ['RELAFFIL', 'SATMTMID', 'CURROPER', 'INSTNM', 'STABBR']

# %%
df_college_2 = df_college.loc[:, different_cols]
df_college_2.head()
# Out:
#    RELAFFIL  SATMTMID  CURROPER                               INSTNM STABBR
# 0         0     420.0         1             Alabama A & M University     AL
# 1         0     565.0         1  University of Alabama at Birmingham     AL
# 2         1       NaN         1                   Amridge University     AL
# 3         0     590.0         1  University of Alabama in Huntsville     AL
# 4         0     430.0         1             Alabama State University     AL

# %%
df_college_2.dtypes
# Out:
# RELAFFIL      int64
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
actual_mem = df_college_2.memory_usage(deep=True)
actual_mem
# Out:
# Index          128
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
original_mem_deep_True = df_college_2.memory_usage(deep=True)
original_mem_deep_True
# Out:
# Index          128
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
original_mem_deep_False = df_college_2.memory_usage(deep=False)
original_mem_deep_False
# Out:
# Index         128
# RELAFFIL    60280
# SATMTMID    60280
# CURROPER    60280
# INSTNM      60280
# STABBR      60280
# dtype: int64

# %%
 df_college_2['RELAFFIL'] = df_college_2['RELAFFIL'].astype(np.int8)

# %%
df_college_2.dtypes
# Out:
# RELAFFIL       int8
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
original_mem_deep_True = df_college_2.memory_usage(deep=True)
original_mem_deep_True
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
# Memory usage for RELAFFIL reduced from 60280 to 7535

# %%
df_college_2.select_dtypes(include=['object']).nunique()
# Out:
# INSTNM    7535
# STABBR      59
# dtype: int64

# %%
df_college_2['STABBR'] = df_college_2['STABBR'].astype('category')

# %%
df_college_2.dtypes
# Out:
# RELAFFIL        int8
# SATMTMID     float64
# CURROPER       int64
# INSTNM        object
# STABBR      category
# dtype: object

# %%
original_mem_deep_True = df_college_2.memory_usage(deep=True)
original_mem_deep_True
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660699
# STABBR       13576
# dtype: int64

# %%
# Memory usage for STABBR reduced from 444565 to 13576

# %%
final_mem = df_college_2.memory_usage(deep=True)
final_mem
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660699
# STABBR       13576
# dtype: int64

# %%
actual_mem / final_mem
# Out:
# Index        1.000000
# RELAFFIL     8.000000
# SATMTMID     1.000000
# CURROPER     1.000000
# INSTNM       0.999305
# STABBR      32.746391
# dtype: float64

# %% [raw]
# Notes:
#
# • Most of the time, objects are called catch_all datatypes
# • Most of the times, they are strings
# • If deep = Flase is given what memory is returned? why?
# • otherwise, all the rows will be given the same memory
#   this will be wrong in case of objects
# • When dtyps are changed to Categorical, internal mappings are created
# • This is unique to Pandas, not available to NUMPY. This takes less memory
# •Range Index is a generator, so occupies LESS MEMORY

# %% [markdown]
# ### 3. Selecting the smallest of the largest

# %%
df_movie = pd.read_csv('data/movie.csv')

# %%
df_movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
df_movie = df_movie[['movie_title', 'imdb_score', 'budget']]
df_movie.head()
# Out:
#                                   movie_title  imdb_score       budget
# 0                                      Avatar         7.9  237000000.0
# 1    Pirates of the Caribbean: At World's End         7.1  300000000.0
# 2                                     Spectre         6.8  245000000.0
# 3                       The Dark Knight Rises         8.5  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens         7.1          NaN

# %%
df_movie_2 = df_movie[['movie_title', 'imdb_score', 'budget']]

# %%
df_movie_2.nlargest(100, 'imdb_score').head()
# Out:
#                    movie_title  imdb_score      budget
# 2725          Towering Inferno         9.5         NaN
# 1920  The Shawshank Redemption         9.3  25000000.0
# 3402             The Godfather         9.2   6000000.0
# 2779                   Dekalog         9.1         NaN
# 4312      Kickboxer: Vengeance         9.1  17000000.0

# %%
df_movie_2.nlargest(100, 'imdb_score').nsmallest(5, 'budget')
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %% [markdown]
# ### 4. Selecting the largest of each group by sorting

# %%
df_movie = pd.read_csv('data/movie.csv')

# %%
df_movie_2 = df_movie[['movie_title', 'title_year', 'imdb_score']]

# %%
df_movie_2.head()
# Out:
#                                   movie_title  title_year  imdb_score
# 0                                      Avatar      2009.0         7.9
# 1    Pirates of the Caribbean: At World's End      2007.0         7.1
# 2                                     Spectre      2015.0         6.8
# 3                       The Dark Knight Rises      2012.0         8.5
# 4  Star Wars: Episode VII - The Force Awakens         NaN         7.1

# %%
df_movie_2.sort_values('title_year', ascending=False).head()
# Out:
#                        movie_title  title_year  imdb_score
# 3884                      The Veil      2016.0         4.7
# 2375    My Big Fat Greek Wedding 2      2016.0         6.1
# 2794          Miracles from Heaven      2016.0         6.8
# 92    Independence Day: Resurgence      2016.0         5.5
# 153                Kung Fu Panda 3      2016.0         7.2

# %%
df_movie_3 = df_movie_2.sort_values(['title_year','imdb_score'],ascending=False)

# %%
df_movie_3.head()
# Out:
#                       movie_title  title_year  imdb_score
# 4312         Kickboxer: Vengeance      2016.0         9.1
# 4277  A Beginner's Guide to Snuff      2016.0         8.7
# 3798                      Airlift      2016.0         8.5
# 27     Captain America: Civil War      2016.0         8.2
# 98            Godzilla Resurgence      2016.0         8.2

# %%
movie_top_year = df_movie_3.drop_duplicates(subset='title_year')

# %%
movie_top_year.head()
# Out:
#                                   movie_title  title_year  imdb_score
# 4312                     Kickboxer: Vengeance      2016.0         9.1
# 3745                          Running Forever      2015.0         8.6
# 4369                   Queen of the Mountains      2014.0         8.7
# 3935  Batman: The Dark Knight Returns, Part 2      2013.0         8.4
# 3                       The Dark Knight Rises      2012.0         8.5

# %%
df_movie_4 = df_movie[['movie_title', 'title_year','content_rating', 'budget']]
df_movie_4_sorted = df_movie_4.sort_values(['title_year', 'content_rating', 'budget'], ascending=[False, False, True])
df_movie_4_sorted.drop_duplicates(subset=['title_year','content_rating']).head(10)
# Out:
#                                           movie_title  title_year  \
# 4026                                        Compadres      2016.0
# 4658                              Fight to the Finish      2016.0
# 4661                                       Rodeo Girl      2016.0
# 3252                                      The Wailing      2016.0
# 4659                   Alleluia! The Devil's Carnival      2016.0
# 4731                                          Bizarre      2015.0
# 812                                  The Ridiculous 6      2015.0
# 4831                                      The Gallows      2015.0
# 4825                                 Romantic Schemer      2015.0
# 3796  R.L. Stine's Monsterville: The Cabinet of Souls      2015.0
#
#      content_rating     budget
# 4026              R  3000000.0
# 4658          PG-13   150000.0
# 4661             PG   500000.0
# 3252      Not Rated        NaN
# 4659            NaN   500000.0
# 4731        Unrated   500000.0
# 812           TV-14        NaN
# 4831              R   100000.0
# 4825          PG-13   125000.0
# 3796             PG  4400000.0

# %%
#keep = 'last'

# %%
df_movie_4_sorted.drop_duplicates(subset=['title_year','content_rating'], keep = 'last').head(10)
# Out:
#            movie_title  title_year content_rating       budget
# 3312             Kicks      2016.0              R          NaN
# 3657              Race      2016.0          PG-13          NaN
# 79     The Jungle Book      2016.0             PG  175000000.0
# 4305       Cabin Fever      2016.0      Not Rated          NaN
# 4605     Irreplaceable      2016.0            NaN          NaN
# 4731           Bizarre      2015.0        Unrated     500000.0
# 812   The Ridiculous 6      2015.0          TV-14          NaN
# 4892            Exeter      2015.0              R          NaN
# 4814    Heroes of Dirt      2015.0          PG-13          NaN
# 3739     Christmas Eve      2015.0             PG          NaN

# %% [markdown]
# ### 5. Replicating nlargest with sort_values

# %%
df_movie = pd.read_csv('data/movie.csv')
df_movie2 = df_movie[['movie_title', 'imdb_score', 'budget']]
df_movie_smallest_largest = df_movie2.nlargest(100, 'imdb_score')\
.nsmallest(5, 'budget')
df_movie_smallest_largest
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %%
df_movie2.sort_values('imdb_score', ascending=False).head(100)
# Out:
#                                   movie_title  imdb_score      budget
# 2725                         Towering Inferno         9.5         NaN
# 1920                 The Shawshank Redemption         9.3  25000000.0
# 3402                            The Godfather         9.2   6000000.0
# 2779                                  Dekalog         9.1         NaN
# 4312                     Kickboxer: Vengeance         9.1  17000000.0
# ...                                       ...         ...         ...
# 3799                     Anne of Green Gables         8.4         NaN
# 3777                      Requiem for a Dream         8.4   4500000.0
# 3935  Batman: The Dark Knight Returns, Part 2         8.4   3500000.0
# 4636                     The Other Dream Team         8.4    500000.0
# 2455                                   Aliens         8.4  18500000.0
#
# [100 rows x 3 columns]

# %%
df_movie2.sort_values('imdb_score', ascending=False).head(100)\
 .sort_values('budget').head()
# Out:
#                     movie_title  imdb_score    budget
# 4815  A Charlie Brown Christmas         8.4  150000.0
# 4801         Children of Heaven         8.5  180000.0
# 4804             Butterfly Girl         8.7  180000.0
# 4706               12 Angry Men         8.9  350000.0
# 4636       The Other Dream Team         8.4  500000.0

# %%
df_movie2.nlargest(100, 'imdb_score').tail()
# Out:
#                 movie_title  imdb_score     budget
# 4023                 Oldboy         8.4  3000000.0
# 4163  To Kill a Mockingbird         8.4  2000000.0
# 4395         Reservoir Dogs         8.4  1200000.0
# 4550           A Separation         8.4   500000.0
# 4636   The Other Dream Team         8.4   500000.0

# %%
df_movie2.sort_values('imdb_score', ascending=False) \
 .head(100).tail()
# Out:
#                                   movie_title  imdb_score      budget
# 3799                     Anne of Green Gables         8.4         NaN
# 3777                      Requiem for a Dream         8.4   4500000.0
# 3935  Batman: The Dark Knight Returns, Part 2         8.4   3500000.0
# 4636                     The Other Dream Team         8.4    500000.0
# 2455                                   Aliens         8.4  18500000.0

# %% [markdown]
# ### 6. Calculating a trailing stop order price

# %%
import pandas_datareader as pdr
tsla = pdr.DataReader('tsla', data_source='yahoo',start='2017-1-1')
tsla.head(8)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-01-03  44.066002  42.192001  42.972000  43.397999  29616500.0  43.397999
# 2017-01-04  45.599998  42.862000  42.950001  45.397999  56067500.0  45.397999
# 2017-01-05  45.495998  44.389999  45.284000  45.349998  29558500.0  45.349998
# 2017-01-06  46.062000  45.090000  45.386002  45.801998  27639500.0  45.801998
# 2017-01-09  46.383999  45.599998  45.793999  46.256001  19897500.0  46.256001
# 2017-01-10  46.400002  45.377998  46.400002  45.973999  18300000.0  45.973999
# 2017-01-11  45.995998  45.335999  45.813999  45.945999  18254000.0  45.945999
# 2017-01-12  46.139999  45.116001  45.812000  45.917999  18951000.0  45.917999

# %%
tsla_close = tsla['Close']
tsla_close.head()
# Out:
# Date
# 2017-01-03    43.397999
# 2017-01-04    45.397999
# 2017-01-05    45.349998
# 2017-01-06    45.801998
# 2017-01-09    46.256001
# Name: Close, dtype: float64

# %%
tsla_cummax = tsla_close.cummax()
tsla_cummax.head(5)
# Out:
# Date
# 2017-01-03    43.397999
# 2017-01-04    45.397999
# 2017-01-05    45.397999
# 2017-01-06    45.801998
# 2017-01-09    46.256001
# Name: Close, dtype: float64

# %%
tsla_trailing_stop = tsla_cummax * .9
tsla_trailing_stop.head()
# Out:
# Date
# 2017-01-03    39.058199
# 2017-01-04    40.858199
# 2017-01-05    40.858199
# 2017-01-06    41.221798
# 2017-01-09    41.630400
# Name: Close, dtype: float64

# %%
def set_trailing_loss(symbol, purchase_date, perc):
    close = pdr.DataReader(symbol, 'yahoo', start=purchase_date)['Close']
    return close.cummax() * perc

# %%
msft_trailing_stop = set_trailing_loss('msft', '2017-6-1', .85)
msft_trailing_stop.head()
# Out:
# Date
# 2017-06-01    59.584999
# 2017-06-02    60.996002
# 2017-06-05    61.437999
# 2017-06-06    61.641997
# 2017-06-07    61.641997
# Name: Close, dtype: float64
